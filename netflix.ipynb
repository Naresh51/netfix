# %% [markdown]
# # NETFLIX

# %% [markdown]
# ### This netflix dataset has information about the TV shows and Movies available  on netflix till 2021.
# ### This dataset collected from fixable which is a third party netflix seach engine ,and available from kaggle website for free

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import warnings 
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Python libraries <br>
# #### A python library is a collection of related modules. It contains bundles of code that can be used repeatedly in different programs. It makes Python Programming simpler and convenient for the programmer.
# ### NUMPY
# #### Numpy is scientific computing library for python and Numpy stands for numerical python.
# ### PANDAS
# #### Pandas is a powerful open source python  data analysis toolkit.
# ### Matplotlib
# #### matplotlib use for data visualization .Matplotlib is 2D and 3D ploting python library .
# ### Seaborn
# #### seaborn is also use for data visualization and support animation.
# ### warnings
# #### warnings  library use for ignoring warnings with the help of warnings filter

# %%
# import dataset
df=pd.read_csv(r"C:\Users\hp\Desktop\netflix_titles-PROJECT.csv")

# %% [markdown]
# ### getting some basic information about the dataset

# %% [markdown]
# #### 1.head()

# %%
df.head() # to show top 5 record of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### 2. shape

# %%
df.shape        # to show the no. of rows and columns
# Out:
# (8807, 12)

# %% [markdown]
# ### 3. tail()

# %%
df.tail()       # to show the bottom 5 records of the dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ### 4. size

# %%
df.size   # to show total no. of elements in the dataset
# Out:
# 105684

# %% [markdown]
# ### 5.columns

# %%
df.columns            # to show ecah columns name
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ### 6.dtypes

# %%
df.dtypes             # to show the data type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### 7. info()

# %%
df.info()         # to show indexes,columns, data types of each columns, memoery at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Task 1. is there any duplicate record in this dataset? if yes then remove the duplicate records.

# %% [markdown]
# ### duplicated()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
# to check row wise and detect the duplicate rows in from of true and flase 
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
'''# but in this dataset do not have any duplicate rows
# if we find any duplicate records in future the we will be use 
df.drop_duplicates()
# use permanentty delete inplace = true
df.drop_duplicates(inplace=True)'''

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ### Task 2. is there any null values present in any columns ? show with heat-map.

# %% [markdown]
# ### isnull()

# %%
df.isnull()           # to show where null value is present give in the form of true and flase
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()                # to show the count o f null values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# calculate null value in persentage
df.isnull().sum()/df.shape[0]*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
df.dropna(subset=['rating','duration','date_added','cast','country'],inplace=True)
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1958
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        26.858711
# cast             0.000000
# country          0.000000
# date_added       0.000000
# release_year     0.000000
# rating           0.000000
# duration         0.000000
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# ### seaborn library( heat-map)

# %%
sns.heatmap(df.isnull())      # using heat-map to show null values count
# Out:
# <AxesSubplot:>

# %%
# saving the dataframe
df.to_csv('netflix1.csv',index=False)

# %% [markdown]
# #  Questions

# %% [markdown]
# ### 1. for "house of cards" , what is the show id and who is the director of this show?

# %% [markdown]
# ### method

# %% [markdown]
# ### 1. isin()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ###  2. str.contains()

# %%
df[df['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### 2.  in which year highest number of the TV shows & Movies were released ? show with Bar Graph.

# %% [markdown]
# ### dtypes

# %% [markdown]
# # df.dtypes

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### to_datetime

# %%
# there is no datetime data type column first of all we will create it

# %%
df['release_year']
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2007
# 8803    2018
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 8807, dtype: int64

# %%
df['date']=pd.to_datetime(df['date_added'])

# %%
df.head()
# Out:
#   show_id     type                          title         director  \
# 1      s2  TV Show                  Blood & Water              NaN
# 4      s5  TV Show                   Kota Factory              NaN
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9     s10    Movie                   The Starling   Theodore Melfi
#
#                                                 cast  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 1                                       South Africa  September 24, 2021
# 4                                              India  September 24, 2021
# ...

# %%
df.drop(['year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   show_id     type                          title         director  \
# 1      s2  TV Show                  Blood & Water              NaN
# 4      s5  TV Show                   Kota Factory              NaN
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9     s10    Movie                   The Starling   Theodore Melfi
#
#                                                 cast  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 1                                       South Africa  September 24, 2021
# 4                                              India  September 24, 2021
# ...

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# date            datetime64[ns]
# dtype: object

# %%
df['year']=df['date'].dt.year
df
# Out:
#      show_id     type                          title         director  \
# 1         s2  TV Show                  Blood & Water              NaN
# 4         s5  TV Show                   Kota Factory              NaN
# 7         s8    Movie                        Sankofa     Haile Gerima
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9        s10    Movie                   The Starling   Theodore Melfi
# ...      ...      ...                            ...              ...
# 8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df.to_csv('netflix2.csv',index=False)

# %% [markdown]
# ### dt.year.value_counts()

# %%
df['year'].value_counts()          # it counts the occurence of all individual years in data column.
# Out:
# 2019    1722
# 2020    1640
# 2018    1404
# 2021    1056
# 2017     989
# 2016     358
# 2015      70
# 2014      20
# 2011      13
# 2013      11
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: year, dtype: int64

# %% [markdown]
# ### Bar Graph

# %%
df['year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3. how many Movies & TV shows are in the dataset ? show with Bar Graph.

# %% [markdown]
# ### groupby

# %%
 #to group all unique items of a column and show their count
df.head()
# Out:
#   show_id     type                          title         director  \
# 1      s2  TV Show                  Blood & Water              NaN
# 4      s5  TV Show                   Kota Factory              NaN
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9     s10    Movie                   The Starling   Theodore Melfi
#
#                                                 cast  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 1                                       South Africa  September 24, 2021
# 4                                              India  September 24, 2021
# ...

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      5277
# TV Show    2013
# Name: type, dtype: int64

# %% [markdown]
# ### countplot()

# %%
# to show the count of all unique values of any column in the form of bar graph
sns.countplot(df['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# ### 4. show only the title of all TV shows that were released in india only

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[(df['type']=='TV Show')&(df["country"]=='India')]
# Out:
#      show_id     type                                  title  \
# 4         s5  TV Show                           Kota Factory
# 39       s40  TV Show                           Chhota Bheem
# 50       s51  TV Show                          Dharmakshetra
# 297     s298  TV Show                               Navarasa
# 918     s919  TV Show                         Lava Ka Dhaava
# ...      ...      ...                                    ...
# 7872   s7873  TV Show                             Rishta.com
# 8121   s8122  TV Show                            Super Bheem
# 8172   s8173  TV Show  Th Eena Meena Deeka Chase Comedy Show
# 8349   s8350  TV Show                 The House That Made Me
# 8775   s8776  TV Show                        Yeh Meri Family
#
#                                                director  \
# 4                                                   NaN
# 39                                                  NaN
# 50                                                  NaN
# ...

# %% [markdown]
# ### 6. show top 10 directors, who give the highest numer of tv show and movie to netfix?

# %%
df1=df['director'].value_counts().head(10)

# %%
sns.countplot(df['director'])
# Out:
# <AxesSubplot:xlabel='director', ylabel='count'>

# %% [markdown]
# ### 7. show all the record where category is movie and type is comdey or country is united kingdom?

# %%
df.head()
# Out:
#   show_id     type                          title         director  \
# 1      s2  TV Show                  Blood & Water              NaN
# 4      s5  TV Show                   Kota Factory              NaN
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9     s10    Movie                   The Starling   Theodore Melfi
#
#                                                 cast  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 1                                       South Africa  September 24, 2021
# 4                                              India  September 24, 2021
# ...

# %%
df[(df['type']=='Movie') & (df['listed_in']=='Comedies')]
# Out:
#      show_id   type                            title              director  \
# 27       s28  Movie                        Grown Ups          Dennis Dugan
# 152     s153  Movie    Janoskians: Untold and Untrue          Brett Weiner
# 182     s183  Movie      Welcome Home Roscoe Jenkins        Malcolm D. Lee
# 342     s343  Movie                      Major Payne           Nick Castle
# 348     s349  Movie                             Poms            Zara Hayes
# ...      ...    ...                              ...                   ...
# 8325   s8326  Movie  The Goods: Live Hard, Sell Hard          Neal Brennan
# 8420   s8421  Movie       The Men Who Stare at Goats          Grant Heslov
# 8536   s8537  Movie                The Trip to Spain  Michael Winterbottom
# 8608   s8609  Movie                 Total Frat Movie      Warren P. Sonoda
# 8730   s8731  Movie                Where's the Money       Scott Zabielski
#
#                                                    cast  \
# ...

# %%
 df[(df['type']=='Movie') & (df['listed_in']=='Comedies') |(df['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8737   s8738    Movie              Why Are We Getting So Fat?
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#                                     director  \
# 8                            Andy Devonshire
# 27                              Dennis Dugan
# 32                                       NaN
# ...

# %% [markdown]
# ### 8. In how many movie and show tom cruise cast?

# %%
df[df['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, date, year]
# Index: []

# %%
df[df['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description       date  year
# 341   Through chance, history and divine interventio... 2021-08-01  2021
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021

# %% [markdown]
# ### 9. what are the diffrent ratings difined by netfix?

# %%
df['rating'].value_counts()
# Out:
# TV-MA       2657
# TV-14       1755
# R            779
# TV-PG        653
# PG-13        470
# PG           275
# TV-Y7        222
# TV-Y         209
# TV-G         158
# NR            62
# G             40
# TV-Y7-FV       4
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %% [markdown]
# ### 10. how many movie got a TV-14 rating in "india"?

# %%
df.head(2)
# Out:
#   show_id     type          title director  \
# 1      s2  TV Show  Blood & Water      NaN
# 4      s5  TV Show   Kota Factory      NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description       date  year
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021
# 4  In a city of coaching centers known to train I... 2021-09-24  2021

# %%
df[(df['type']=='Movie') &(df['rating']=='TV-14')&(df['country']=='India')]
# Out:
#      show_id   type                  title              director  \
# 24       s25  Movie                  Jeans            S. Shankar
# 105     s106  Movie       Angamaly Diaries  Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam          Rahul Rawail
# 118     s119  Movie                Gurgaon         Shanker Raman
# 126     s127  Movie                Shikara    Vidhu Vinod Chopra
# ...      ...    ...                    ...                   ...
# 8770   s8771  Movie                Yaadein          Subhash Ghai
# 8771   s8772  Movie       Yaara O Dildaara    Ksshitij Chaudhary
# 8772   s8773  Movie  Yamla Pagla Deewana 2        Sangeeth Sivan
# 8799   s8800  Movie                  Zenda        Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan           Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %% [markdown]
# ### 11.  how many movie got a R rating after relaese 2018?

# %%
df[(df['type']=='Movie') &(df['rating']=="R")&(df['year']>=2018)]
# Out:
#      show_id   type                        title               director  \
# 46       s47  Movie                   Safe House        Daniel Espinosa
# 48       s49  Movie                 Training Day          Antoine Fuqua
# 81       s82  Movie                         Kate  Cedric Nicolas-Troyan
# 122     s123  Movie                   In the Cut           Jane Campion
# 131     s132  Movie  Blade Runner: The Final Cut           Ridley Scott
# ...      ...    ...                          ...                    ...
# 8751   s8752  Movie              Wish I Was Here             Zach Braff
# 8754   s8755  Movie                       Wolves        Bart Freundlich
# 8791   s8792  Movie                  Young Adult          Jason Reitman
# 8802   s8803  Movie                       Zodiac          David Fincher
# 8804   s8805  Movie                   Zombieland        Ruben Fleischer
#
#                                                    cast  \
# ...
